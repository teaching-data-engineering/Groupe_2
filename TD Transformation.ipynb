# %% [markdown]
# # TD Transformation

# %% [markdown]
# ## 1. Enrichissement

# %% [markdown]
# Import des données

# %%
import pandas as pd

# Import du fichier data_NY
df = pd.read_csv("data_NY.csv")

# Supprimer les colonnes inutiles
df = pd.read_csv("data_NY.csv").drop(columns=["Unnamed: 0", "streamingEvent", "pinIconSrc", "watchLiveText", "isPlus", "callToActionText", "timezone", "displayRule", "locale", "date_range"])

# Convertir les colonnes en datetime
df['startsAt'] = pd.to_datetime(df['startsAt'], errors='coerce')
df['endsAt'] = pd.to_datetime(df['endsAt'], errors='coerce')

df.head()
# Out:
#                                       artistImageSrc  \
# 0  https://photos.bandsintown.com/thumb/13985339....
# 1  https://photos.bandsintown.com/thumb/12163906....
# 2  https://photos.bandsintown.com/thumb/17578563....
# 3  https://assets.prod.bandsintown.com/images/hom...
# 4  https://assets.prod.bandsintown.com/images/hom...
#
#                                properlySizedImageURL  \
# 0  https://media.bandsintown.com/110x110/13985339...
# 1  https://media.bandsintown.com/110x110/12163906...
# 2  https://media.bandsintown.com/110x110/17578563...
# 3  https://assets.prod.bandsintown.com/images/hom...
# 4  https://assets.prod.bandsintown.com/images/hom...
#
#                              callToActionRedirectUrl  \
# 0  https://www.bandsintown.com/e/105307658-emily-...
# 1  https://www.bandsintown.com/e/105660087-john-f...
# 2  https://www.bandsintown.com/e/105917670-songbi...
# 3  https://www.bandsintown.com/e/1032435913-stere...
# 4  https://www.bandsintown.com/e/1032519750-il-tr...
#
#                                     fallbackImageUrl               artistName  \
# 0  https://assets.prod.bandsintown.com/images/hom...               Emily Beck
# 1  https://assets.prod.bandsintown.com/images/hom...               John Finch
# 2  https://assets.prod.bandsintown.com/images/hom...  Songbird Official Music
# 3  https://assets.prod.bandsintown.com/images/hom...             StereoPhonic
# 4  https://assets.prod.bandsintown.com/images/hom...             Il Trovatore
#
#                         venueName                                    title  \
# 0  John Jay Homestead Farm Market     Emily Beck at the John Jay Homestead
# 1              St Mary's Winfield  St. Mary's Winfield High School Retreat
# 2         The Grove at Shrewsbury             The Grove at Shrewsbury West
# 3             John Golden Theatre                                      NaN
# 4              Metropolitan Opera                                      NaN
#
#         locationText                                           eventUrl  \
# 0        Katonah, NY  https://www.bandsintown.com/e/105307658-emily-...
# 1         Queens, NY  https://www.bandsintown.com/e/105660087-john-f...
# 2     Shrewsbury, NJ  https://www.bandsintown.com/e/105917670-songbi...
# 3  New York City, NY  https://www.bandsintown.com/e/1032435913-stere...
# 4       New York, NY  https://www.bandsintown.com/e/1032519750-il-tr...
#
#                                            artistUrl rsvpCount  rsvpCountInt  \
# 0  https://www.bandsintown.com/a/14545332-emily-b...         0             0
# 1  https://www.bandsintown.com/a/2115895-john-fin...         0             0
# 2  https://www.bandsintown.com/a/15507503-songbir...         0             0
# 3  https://www.bandsintown.com/a/2449338-stereoph...         0             0
# 4  https://www.bandsintown.com/a/29288-il-trovato...         0             0
#
#              startsAt              endsAt
# 0 2024-10-26 11:00:00 2024-10-26 13:00:00
# 1 2024-10-26 12:00:00                 NaT
# 2 2024-10-26 12:00:00 2024-10-26 15:00:00
# 3 2024-10-26 13:00:00                 NaT
# 4 2024-10-26 13:00:00                 NaT

# %% [markdown]
# Durée de l'évènement

# %%
df['event_duration'] = round((df['endsAt'] - df['startsAt']).dt.total_seconds() / 3600, 1)  # durée en heures

df[['startsAt', 'endsAt', 'event_duration']]
# Out:
#                 startsAt              endsAt  event_duration
# 0    2024-10-26 11:00:00 2024-10-26 13:00:00             2.0
# 1    2024-10-26 12:00:00                 NaT             NaN
# 2    2024-10-26 12:00:00 2024-10-26 15:00:00             3.0
# 3    2024-10-26 13:00:00                 NaT             NaN
# 4    2024-10-26 13:00:00                 NaT             NaN
# ...                  ...                 ...             ...
# 7064 2024-10-13 22:15:00                 NaT             NaN
# 7065 2024-10-13 22:30:00 2024-10-13 23:59:00             1.5
# 7066 2024-10-13 23:00:00 2024-10-13 23:30:00             0.5
# 7067 2024-10-13 23:00:00                 NaT             NaN
# 7068 2024-10-13 23:00:00                 NaT             NaN
#
# [7069 rows x 3 columns]

# %% [markdown]
# Week-end ou non

# %%
df['is_weekend'] = df['startsAt'].dt.weekday >= 5  # 5 = samedi, 6 = dimanche

df[['startsAt', 'is_weekend']]
# Out:
#                 startsAt  is_weekend
# 0    2024-10-26 11:00:00        True
# 1    2024-10-26 12:00:00        True
# 2    2024-10-26 12:00:00        True
# 3    2024-10-26 13:00:00        True
# 4    2024-10-26 13:00:00        True
# ...                  ...         ...
# 7064 2024-10-13 22:15:00        True
# 7065 2024-10-13 22:30:00        True
# 7066 2024-10-13 23:00:00        True
# 7067 2024-10-13 23:00:00        True
# 7068 2024-10-13 23:00:00        True
#
# [7069 rows x 2 columns]

# %% [markdown]
# Segmentation - popularité

# %%
# Calcul des quartiles
Q1 = df['rsvpCountInt'].quantile(0.25)  # Premier quartile
Q2 = df['rsvpCountInt'].quantile(0.50)  # Médiane (deuxième quartile)
Q3 = df['rsvpCountInt'].quantile(0.75)  # Troisième quartile

# Fonction de segmentation basée sur les quartiles
def segment_rsvp(rsvp_count):
    if rsvp_count <= Q1:
        return 'Low'
    elif Q1 < rsvp_count <= Q2:
        return 'Medium'
    elif Q2 < rsvp_count <= Q3:
        return 'High'
    else:
        return 'Very High'

# Appliquer la fonction pour créer une nouvelle colonne 'popularity'
df['popularity'] = df['rsvpCountInt'].apply(segment_rsvp)

# %% [markdown]
# Nationalité

# %%
import requests
import pandas as pd

def get_artist_info_wikidata(artist_name):
    try:
        # Effectuer une recherche sur Wikidata pour l'artiste
        url = f'https://www.wikidata.org/w/api.php?action=wbsearchentities&search={artist_name}&language=en&limit=5&format=json'
        response = requests.get(url)
        response.raise_for_status()  # Vérifie les erreurs de statut HTTP
        
        # Vérifier si la réponse contient des résultats
        if not response.json()['search']:
            return pd.Series([pd.NA])
        
        # Récupérer l'ID de l'entité (exemple: Q123456)
        artist_id = response.json()['search'][0]['id']
        
        # Requête pour obtenir des informations détaillées sur l'artiste
        entity_url = f'https://www.wikidata.org/w/api.php?action=wbgetentities&ids={artist_id}&props=labels|descriptions&languages=en&format=json'
        entity_response = requests.get(entity_url)
        entity_response.raise_for_status()
        
        # Extraire les informations de l'artiste
        data = entity_response.json()
        artist_data = data['entities'][artist_id]
        
        # Récupérer la description disponible
        description = artist_data['descriptions'].get('en', {}).get('value', pd.NA)

        return pd.Series([description])
    
    except requests.exceptions.RequestException as e:
        return pd.Series([pd.NA])

# Appliquer la fonction à chaque nom d'artiste et ajouter les résultats au DataFrame
df['description'] = df['artistName'].apply(get_artist_info_wikidata)

# Si vous voulez enregistrer ce DataFrame dans un fichier CSV
df.to_csv("data_enrichies.csv", index=False)

# %%
import pandas as pd

df = pd.read_csv('data_enrichies.csv')

# %%
import re

# Nettoyage de la colonne 'description' en remplaçant certains termes par pd.NA
df['description'] = df['description'].apply(lambda x: pd.NA if any(term in str(x) for term in ['given name', 'family name']) else x)

# Remplacement des ORCID par pd.NA avec une meilleure correspondance pour l'expression régulière
df['description'] = df['description'].apply(lambda x: pd.NA if isinstance(x, str) and re.search(r'researcher \(ORCID \d{4}-\d{4}-\d{4}-\d{4}[A-Za-z]?\)', x) else x)

# %%
df
# Out:
#                                          artistImageSrc  \
# 0     https://photos.bandsintown.com/thumb/13985339....
# 1     https://photos.bandsintown.com/thumb/12163906....
# 2     https://photos.bandsintown.com/thumb/17578563....
# 3     https://assets.prod.bandsintown.com/images/hom...
# 4     https://assets.prod.bandsintown.com/images/hom...
# ...                                                 ...
# 7064  https://photos.bandsintown.com/thumb/17491803....
# 7065  https://photos.bandsintown.com/thumb/17350358....
# 7066  https://photos.bandsintown.com/thumb/12169306....
# 7067  https://photos.bandsintown.com/thumb/7170653.jpeg
# 7068  https://photos.bandsintown.com/thumb/9102015.jpeg
#
#                                   properlySizedImageURL  \
# 0     https://media.bandsintown.com/110x110/13985339...
# 1     https://media.bandsintown.com/110x110/12163906...
# 2     https://media.bandsintown.com/110x110/17578563...
# 3     https://assets.prod.bandsintown.com/images/hom...
# 4     https://assets.prod.bandsintown.com/images/hom...
# ...                                                 ...
# 7064  https://media.bandsintown.com/110x110/17491803...
# 7065  https://media.bandsintown.com/110x110/17350358...
# 7066  https://media.bandsintown.com/110x110/12169306...
# 7067  https://media.bandsintown.com/110x110/7170653....
# 7068  https://media.bandsintown.com/110x110/9102015....
#
#                                 callToActionRedirectUrl  \
# 0     https://www.bandsintown.com/e/105307658-emily-...
# 1     https://www.bandsintown.com/e/105660087-john-f...
# 2     https://www.bandsintown.com/e/105917670-songbi...
# 3     https://www.bandsintown.com/e/1032435913-stere...
# 4     https://www.bandsintown.com/e/1032519750-il-tr...
# ...                                                 ...
# 7064  https://www.bandsintown.com/e/1032332991-t.i.-...
# 7065  https://www.bandsintown.com/e/105635483-the-da...
# 7066  https://www.bandsintown.com/e/105801395-mark-a...
# 7067  https://www.bandsintown.com/e/1033084776-miss-...
# 7068  https://www.bandsintown.com/e/1033144003-nio-g...
#
#                                        fallbackImageUrl  \
# 0     https://assets.prod.bandsintown.com/images/hom...
# 1     https://assets.prod.bandsintown.com/images/hom...
# 2     https://assets.prod.bandsintown.com/images/hom...
# 3     https://assets.prod.bandsintown.com/images/hom...
# 4     https://assets.prod.bandsintown.com/images/hom...
# ...                                                 ...
# 7064  https://assets.prod.bandsintown.com/images/hom...
# 7065  https://assets.prod.bandsintown.com/images/hom...
# 7066  https://assets.prod.bandsintown.com/images/hom...
# 7067  https://assets.prod.bandsintown.com/images/hom...
# 7068  https://assets.prod.bandsintown.com/images/hom...
#
#                    artistName                                      venueName  \
# 0                  Emily Beck                 John Jay Homestead Farm Market
# 1                  John Finch                             St Mary's Winfield
# 2     Songbird Official Music                        The Grove at Shrewsbury
# 3                StereoPhonic                            John Golden Theatre
# 4                Il Trovatore                             Metropolitan Opera
# ...                       ...                                            ...
# 7064                     T.I.                      City Winery New York City
# 7065       The Dang-it Bobbys                             Pete's Candy Store
# 7066             Mark Anthony                         TAO Downtown Nightclub
# 7067            Miss Jennifer  Somewhere Nowhere NYC - Lounge & Rooftop Pool
# 7068               Nio garcia                                   Code Astoria
#
#                                         title       locationText  \
# 0        Emily Beck at the John Jay Homestead        Katonah, NY
# 1     St. Mary's Winfield High School Retreat         Queens, NY
# 2                The Grove at Shrewsbury West     Shrewsbury, NJ
# 3                                         NaN  New York City, NY
# 4                                         NaN       New York, NY
# ...                                       ...                ...
# 7064                                      NaN  New York City, NY
# 7065                                      NaN       Brooklyn, NY
# 7066          MARK ANTHONY @ TAO DOWNTOWN NYC  New York City, NY
# 7067                                      NaN       New York, NY
# 7068                                      NaN       Flushing, NY
#
#                                                eventUrl  \
# 0     https://www.bandsintown.com/e/105307658-emily-...
# 1     https://www.bandsintown.com/e/105660087-john-f...
# 2     https://www.bandsintown.com/e/105917670-songbi...
# 3     https://www.bandsintown.com/e/1032435913-stere...
# 4     https://www.bandsintown.com/e/1032519750-il-tr...
# ...                                                 ...
# 7064  https://www.bandsintown.com/e/1032332991-t.i.-...
# 7065  https://www.bandsintown.com/e/105635483-the-da...
# 7066  https://www.bandsintown.com/e/105801395-mark-a...
# 7067  https://www.bandsintown.com/e/1033084776-miss-...
# 7068  https://www.bandsintown.com/e/1033144003-nio-g...
#
#                                               artistUrl rsvpCount  \
# 0     https://www.bandsintown.com/a/14545332-emily-b...         0
# 1     https://www.bandsintown.com/a/2115895-john-fin...         0
# 2     https://www.bandsintown.com/a/15507503-songbir...         0
# 3     https://www.bandsintown.com/a/2449338-stereoph...         0
# 4     https://www.bandsintown.com/a/29288-il-trovato...         0
# ...                                                 ...       ...
# 7064  https://www.bandsintown.com/a/5-t.i.?came_from...        31
# 7065  https://www.bandsintown.com/a/490968-the-dang-...         0
# 7066  https://www.bandsintown.com/a/263263-mark-anth...         0
# 7067  https://www.bandsintown.com/a/7870982-miss-jen...         1
# 7068  https://www.bandsintown.com/a/14138816-nio-gar...         3
#
#       rsvpCountInt             startsAt               endsAt  event_duration  \
# 0                0  2024-10-26 11:00:00  2024-10-26 13:00:00             2.0
# 1                0  2024-10-26 12:00:00                  NaN             NaN
# 2                0  2024-10-26 12:00:00  2024-10-26 15:00:00             3.0
# 3                0  2024-10-26 13:00:00                  NaN             NaN
# 4                0  2024-10-26 13:00:00                  NaN             NaN
# ...            ...                  ...                  ...             ...
# 7064            31  2024-10-13 22:15:00                  NaN             NaN
# 7065             0  2024-10-13 22:30:00  2024-10-13 23:59:00             1.5
# 7066             0  2024-10-13 23:00:00  2024-10-13 23:30:00             0.5
# 7067             1  2024-10-13 23:00:00                  NaN             NaN
# 7068             3  2024-10-13 23:00:00                  NaN             NaN
#
#       is_weekend popularity                                        description
# 0           True        Low                                               <NA>
# 1           True        Low                      English diplomat; (1626-1682)
# 2           True        Low                                                NaN
# 3           True        Low  method of sound reproduction using two audio c...
# 4           True        Low                            opera by Giuseppe Verdi
# ...          ...        ...                                                ...
# 7064        True  Very High                          American rapper and actor
# 7065        True        Low                                                NaN
# 7066        True        Low       Roman politician and general (83 BC – 30 BC)
# 7067        True     Medium     recipient of a New Zealand Suffrage Medal 1993
# 7068        True       High                                Puerto Rican singer
#
# [7069 rows x 18 columns]
